# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Task (1) Dataset.csv')

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 522   11:15:00      Friday              31-50          Male
# 4348   7:30:00    Thursday              18-30          Male
# 8302  19:15:00      Monday              18-30          Male
# 720   17:50:00      Friday           Under 18          Male
# 5054  13:38:00      Sunday              18-30          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 522   Junior high school                Employee             5-10yr
# 4348   Elementary school                Employee             5-10yr
# 8302  Junior high school                Employee          Below 1yr
# 720   Junior high school                Employee              1-2yr
# 5054  Junior high school                Employee              2-5yr
#
#      Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 522       Automobile            Owner                  2-5yrs  ...
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df.sample(5)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 354     6:00:00      Sunday              18-30          Male
# 6753   16:10:00      Friday              18-30          Male
# 11831  22:10:00   Wednesday              31-50          Male
# 2043   20:40:00     Tuesday              31-50          Male
# 3526   18:10:00   Wednesday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 354     Above high school                   Owner             5-10yr
# 6753   Junior high school                Employee         Above 10yr
# 11831   Elementary school                Employee         Above 10yr
# 2043   Junior high school                Employee             5-10yr
# 3526   Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 354         Automobile            Owner              Above 10yr  ...
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2889 entries, 8 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         2889 non-null   object
#  1   Day_of_week                  2889 non-null   object
#  2   Age_band_of_driver           2889 non-null   object
#  3   Sex_of_driver                2889 non-null   object
#  4   Educational_level            2889 non-null   object
#  5   Vehicle_driver_relation      2889 non-null   object
#  6   Driving_experience           2889 non-null   object
#  7   Type_of_vehicle              2889 non-null   object
#  8   Owner_of_vehicle             2889 non-null   object
#  9   Service_year_of_vehicle      2889 non-null   object
#  10  Defect_of_vehicle            2889 non-null   object
#  11  Area_accident_occured        2889 non-null   object
#  12  Lanes_or_Medians             2889 non-null   object
# ...

# %%
df['Type_of_vehicle'] = df['Type_of_vehicle'].replace('car', 'Truck')
print(df['Type_of_vehicle'].unique())
df.head()
# Out:
# ['Lorry (41?100Q)' 'Automobile' 'Public (> 45 seats)' 'Long lorry'
#  'Lorry (11?40Q)' 'Taxi' 'Public (12 seats)' 'Ridden horse' 'Other'
#  'Pick up upto 10Q' 'Bajaj' 'Public (13?45 seats)' 'Motorcycle'
#  'Stationwagen' 'Special vehicle' 'Turbo' 'Bicycle']
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 12  17:45:00    Thursday              18-30          Male  Junior high school
# 13  17:45:00    Thursday              31-50          Male  Junior high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
#
#    Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 8                 Employee         Above 10yr      Lorry (41?100Q)
# 9                 Employee              1-2yr           Automobile
# ...

# %%
def clean_data(column):
  return column.split()[0]

# Apply the function to the Mileage column
df['Type_of_vehicle'] = df['Type_of_vehicle'].apply(clean_data)

# %%
df.head()
# Out:
#                   Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8  2024-07-25 17:20:00      Friday              18-30          Male
# 9  2024-07-25 17:20:00      Friday              18-30          Male
# 12 2024-07-25 17:45:00    Thursday              18-30          Male
# 13 2024-07-25 17:45:00    Thursday              31-50          Male
# 14 2024-07-25 17:45:00    Thursday              31-50          Male
#
#      Educational_level Vehicle_driver_relation Driving_experience  \
# 8   Junior high school                Employee         Above 10yr
# 9   Junior high school                Employee              1-2yr
# 12  Junior high school                Employee              1-2yr
# 13  Junior high school                Employee             5-10yr
# 14  Junior high school                Employee         Above 10yr
#
#    Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 8            Lorry            Owner                   1-2yr  ...
# ...

# %%
df.dtypes
# Out:
# Time                            object
# Day_of_week                     object
# Age_band_of_driver              object
# Sex_of_driver                   object
# Educational_level               object
# Vehicle_driver_relation         object
# Driving_experience              object
# Type_of_vehicle                 object
# Owner_of_vehicle                object
# Service_year_of_vehicle         object
# Defect_of_vehicle               object
# Area_accident_occured           object
# Lanes_or_Medians                object
# Road_allignment                 object
# Types_of_Junction               object
# Road_surface_type               object
# Road_surface_conditions         object
# Light_conditions                object
# Weather_conditions              object
# Type_of_collision               object
# Number_of_vehicles_involved    float64
# Number_of_casualties             int64
# Vehicle_movement                object
# Casualty_class                  object
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# <ipython-input-197-1bfd8981fe14>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df.dtypes
# Out:
# Time                           datetime64[ns]
# Day_of_week                            object
# Age_band_of_driver                     object
# Sex_of_driver                          object
# Educational_level                      object
# Vehicle_driver_relation                object
# Driving_experience                     object
# Type_of_vehicle                        object
# Owner_of_vehicle                       object
# Service_year_of_vehicle                object
# Defect_of_vehicle                      object
# Area_accident_occured                  object
# Lanes_or_Medians                       object
# Road_allignment                        object
# Types_of_Junction                      object
# Road_surface_type                      object
# Road_surface_conditions                object
# Light_conditions                       object
# Weather_conditions                     object
# Type_of_collision                      object
# ...

# %%
df['Day_of_week'] = pd.Categorical(df['Day_of_week'], categories=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], ordered=True)

# %%
df.dtypes
# Out:
# Time                           datetime64[ns]
# Day_of_week                          category
# Age_band_of_driver                     object
# Sex_of_driver                          object
# Educational_level                      object
# Vehicle_driver_relation                object
# Driving_experience                     object
# Type_of_vehicle                        object
# Owner_of_vehicle                       object
# Service_year_of_vehicle                object
# Defect_of_vehicle                      object
# Area_accident_occured                  object
# Lanes_or_Medians                       object
# Road_allignment                        object
# Types_of_Junction                      object
# Road_surface_type                      object
# Road_surface_conditions                object
# Light_conditions                       object
# Weather_conditions                     object
# Type_of_collision                      object
# ...

# %%
df.dtypes
# Out:
# Time                           datetime64[ns]
# Day_of_week                          category
# Age_band_of_driver                     object
# Sex_of_driver                          object
# Educational_level                      object
# Vehicle_driver_relation                object
# Driving_experience                     object
# Type_of_vehicle                        object
# Owner_of_vehicle                       object
# Service_year_of_vehicle                object
# Defect_of_vehicle                      object
# Area_accident_occured                  object
# Lanes_or_Medians                       object
# Road_allignment                        object
# Types_of_Junction                      object
# Road_surface_type                      object
# Road_surface_conditions                object
# Light_conditions                       object
# Weather_conditions                     object
# Type_of_collision                      object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  2889.000000           2889.000000
# mean                      2.011076              1.529249
# std                       0.635308              0.993012
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df1=df['Number_of_vehicles_involved'].max()
print(df1)
# Out:
# 7.0

# %%
df2=df['Number_of_vehicles_involved'].min()
print(df2)
df3=df['Number_of_vehicles_involved'].mean()
print(df3)
df4=df['Number_of_vehicles_involved'].median()
print(df4)
df5=df['Number_of_vehicles_involved'].mode()
print(df5)
# Out:
# 1.0
# 2.0110764970578057
# 2.0
# 0    2.0
# Name: Number_of_vehicles_involved, dtype: float64

# %%
df[df['Number_of_vehicles_involved'] > 2]
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 95     17:35:00    Thursday              18-30          Male
# 111    20:00:00      Monday            Over 51          Male
# 188    16:20:00      Friday            Over 51       Unknown
# 226     9:25:00     Tuesday            Unknown        Female
# 227     9:25:00     Tuesday            Unknown        Female
# ...         ...         ...                ...           ...
# 12204   7:50:00      Friday              31-50          Male
# 12216  13:57:00   Wednesday            Unknown          Male
# 12219   7:44:00      Friday              18-30          Male
# 12241   6:00:00      Sunday            Unknown          Male
# 12255  20:15:00      Monday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 95     Junior high school                Employee              2-5yr
# 111     Elementary school                Employee              1-2yr
# ...

# %%
df[df['Age_band_of_driver'] == '18-30']
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# 12     17:45:00    Thursday              18-30          Male
# 19      8:20:00     Tuesday              18-30          Male
# 21     15:10:00    Thursday              18-30          Male
# ...         ...         ...                ...           ...
# 12275  15:08:00      Monday              18-30          Male
# 12297  12:30:00    Thursday              18-30          Male
# 12298  18:45:00   Wednesday              18-30          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 8      Junior high school                Employee         Above 10yr
# 9      Junior high school                Employee              1-2yr
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
common_causes = df['Cause_of_accident'].value_counts()
print(common_causes)
# Out:
# Cause_of_accident
# No distancing                           559
# Changing lane to the right              424
# Driving carelessly                      337
# Changing lane to the left               310
# No priority to vehicle                  277
# Moving Backward                         268
# No priority to pedestrian               160
# Other                                    98
# Overtaking                               97
# Driving under the influence of drugs     89
# Driving to the left                      67
# Getting off the vehicle improperly       44
# Driving at high speed                    43
# Overturning                              43
# Turnover                                 28
# Overspeed                                20
# Overloading                              13
# Drunk driving                             5
# Unknown                                   4
# Improper parking                          3
# Name: count, dtype: int64

# %%
df['Age_band_of_driver'].mode()
# Out:
# 0    18-30
# Name: Age_band_of_driver, dtype: object

# %%
accident_severity_by_weather = df.groupby('Weather_conditions')['Accident_severity'].value_counts(normalize=True)
print(accident_severity_by_weather)
# Out:
# Weather_conditions  Accident_severity
# Cloudy              Slight Injury        0.833333
#                     Serious Injury       0.166667
# Normal              Slight Injury        0.848446
#                     Serious Injury       0.138782
#                     Fatal injury         0.012771
# Other               Slight Injury        0.878378
#                     Serious Injury       0.121622
# Raining             Slight Injury        0.875776
#                     Serious Injury       0.121118
#                     Fatal injury         0.003106
# Raining and Windy   Slight Injury        1.000000
# Snow                Slight Injury        0.923077
#                     Serious Injury       0.076923
# Unknown             Slight Injury        0.863014
#                     Serious Injury       0.136986
# Windy               Slight Injury        0.884615
#                     Serious Injury       0.115385
# Name: proportion, dtype: float64

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(x='Type_of_vehicle', data=df,color='green',)
plt.title('Distribution of Type of Vehicle')
plt.xlabel('Type of Vehicle')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a cross-tabulation of Age_band_of_driver and Accident_severity
cross_tab = pd.crosstab(df['Age_band_of_driver'], df['Accident_severity'])

# Create a heatmap to visualize the relationship
plt.figure(figsize=(12, 8))
sns.heatmap(cross_tab, annot=True, cmap='viridis', fmt='d')
plt.title('Relationship between Age Band of Driver and Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Age Band of Driver')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(x='Cause_of_accident', data=df, order=df['Cause_of_accident'].value_counts().index)
plt.title('Common Causes of Accidents')
plt.xlabel('Cause of Accident')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
accident_severity_by_weather = df.groupby('Weather_conditions')['Accident_severity'].value_counts(normalize=True)
accident_severity_by_weather = accident_severity_by_weather.unstack()

accident_severity_by_weather.plot(kind='bar', figsize=(12, 6))
plt.title('Accident Severity by Weather Conditions')
plt.xlabel('Weather Conditions')
plt.ylabel('Proportion')
plt.xticks(rotation=45)
plt.legend(title='Accident Severity')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Age_band_of_driver', y='Accident_severity', data=df, c='red')
plt.title('Relationship between Age Band of Driver and Accident Severity')
# Out:
# Text(0.5, 1.0, 'Relationship between Age Band of Driver and Accident Severity')

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Age_band_of_driver'])
plt.title('Distribution of Age Band of Driver')
plt.xlabel('Age Band')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# The code you provided performs exploratory data analysis on a traffic accident dataset and visualizes the relationships between different features.

# %% [markdown]
# The most common causes of accidents are "No distancing" and "Changing lane to the right".
# Accident severity is not significantly affected by different weather conditions.

# %% [markdown]
# Younger drivers (18-30) tend to have a higher number of severe accidents.
